# %%
import pandas as pd
import numpy as np
import datetime
from datetime import datetime




adress1 = r"Real_Estate_Sales_2001-2020_GL 1.parquet"
adress2 = r"Real_Estate_Sales_2001-2020_GL 2.parquet"
df_1 = pd.read_parquet(adress1)
df_2 = pd.read_parquet(adress2)

df = pd.concat([df_1,df_2])
df
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 0             2020348       2020    2021-09-13        Ansonia
# 1               20002       2020    2020-10-02        Ashford
# 2              200212       2020    2021-03-09           Avon
# 3              200243       2020    2021-04-13           Avon
# 4              200377       2020    2021-07-02           Avon
# ...               ...        ...           ...            ...
# 997208         190272       2019    2020-06-24     New London
# 997209         190284       2019    2019-11-27      Waterbury
# 997210         190129       2019    2020-04-27  Windsor Locks
# 997211         190504       2019    2020-06-03     Middletown
# 997212         190344       2019    2019-12-20        Milford
#
#                       Address  Assessed Value  Sale Amount  Sales Ratio  \
# 0             230 WAKELEE AVE        150500.0     325000.0     0.463000
# 1             390 TURNPIKE RD        253000.0     430000.0     0.588300
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 997213 entries, 0 to 997212
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Serial Number     997213 non-null  int64
#  1   List Year         997213 non-null  int64
#  2   Date Recorded     997211 non-null  datetime64[ns]
#  3   Town              997213 non-null  object
#  4   Address           997162 non-null  object
#  5   Assessed Value    997213 non-null  float64
#  6   Sale Amount       997213 non-null  float64
#  7   Sales Ratio       997213 non-null  float64
#  8   Property Type     614767 non-null  object
#  9   Residential Type  608904 non-null  object
#  10  Non Use Code      289681 non-null  object
#  11  Assessor Remarks  149864 non-null  object
#  12  OPM remarks       9934 non-null    object
#  13  Location          197697 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(2), object(8)
# memory usage: 106.5+ MB

# %%
#Change date to format as text type object and changed back to date type object

df["Date Recorded"] = df["Date Recorded"].dt.strftime("%d/%m/%Y")
df["Date Recorded"] = pd.to_datetime(df["Date Recorded"], format = "%d/%m/%Y")

df
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 0             2020348       2020    2021-09-13        Ansonia
# 1               20002       2020    2020-10-02        Ashford
# 2              200212       2020    2021-03-09           Avon
# 3              200243       2020    2021-04-13           Avon
# 4              200377       2020    2021-07-02           Avon
# ...               ...        ...           ...            ...
# 997208         190272       2019    2020-06-24     New London
# 997209         190284       2019    2019-11-27      Waterbury
# 997210         190129       2019    2020-04-27  Windsor Locks
# 997211         190504       2019    2020-06-03     Middletown
# 997212         190344       2019    2019-12-20        Milford
#
#                       Address  Assessed Value  Sale Amount  Sales Ratio  \
# 0             230 WAKELEE AVE        150500.0     325000.0     0.463000
# 1             390 TURNPIKE RD        253000.0     430000.0     0.588300
# ...

# %%
#Set index
df["Index"] = list(range(1,df.shape[0]+1))
df.set_index("Index", inplace = True)
df
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# Index
# 1             2020348       2020    2021-09-13        Ansonia
# 2               20002       2020    2020-10-02        Ashford
# 3              200212       2020    2021-03-09           Avon
# 4              200243       2020    2021-04-13           Avon
# 5              200377       2020    2021-07-02           Avon
# ...               ...        ...           ...            ...
# 997209         190272       2019    2020-06-24     New London
# 997210         190284       2019    2019-11-27      Waterbury
# 997211         190129       2019    2020-04-27  Windsor Locks
# 997212         190504       2019    2020-06-03     Middletown
# 997213         190344       2019    2019-12-20        Milford
#
#                       Address  Assessed Value  Sale Amount  Sales Ratio  \
# Index
# 1             230 WAKELEE AVE        150500.0     325000.0     0.463000
# ...

# %%
#Number of property types ordered from largest to smallest
df["Property Type"].value_counts().reset_index()
# Out:
#      Property Type   count
# 0    Single Family  401612
# 1            Condo  105420
# 2      Residential   60728
# 3       Two Family   26408
# 4     Three Family   12586
# 5      Vacant Land    3163
# 6      Four Family    2150
# 7       Commercial    1981
# 8       Apartments     486
# 9       Industrial     228
# 10  Public Utility       5

# %%
#Number of residential types ordered from largest to smallest
df["Residential Type"].value_counts().reset_index()
# Out:
#   Residential Type   count
# 0    Single Family  445016
# 1            Condo  117780
# 2       Two Family   29609
# 3     Three Family   14081
# 4      Four Family    2418

# %%
#Number of towns ordered from largest to smallest
df["Town"].value_counts().reset_index()
# Out:
#               Town  count
# 0       Bridgeport  34201
# 1         Stamford  32529
# 2        Waterbury  28506
# 3          Norwalk  23960
# 4        New Haven  21346
# ..             ...    ...
# 165       Hartland    448
# 166       Scotland    430
# 167         Canaan    429
# 168          Union    261
# 169  ***Unknown***      1
#
# [170 rows x 2 columns]

# %%
#Number of assesor remarks ordered from largest to smallest
df["Assessor Remarks"].value_counts().reset_index()
# Out:
#                                         Assessor Remarks  count
# 0                                            ESTATE SALE   5044
# 1                                           BELOW MARKET   2568
# 2                                             SHORT SALE   2510
# 3                                       NEW CONSTRUCTION   2048
# 4                                            FORECLOSURE   1847
# ...                                                  ...    ...
# 66503                                    LACK OF PARKING      1
# 66504  estate sale;per verification house substan wor...      1
# 66505                            SOLD W/ GARAGE UNIT G-1      1
# 66506                        sold less than market value      1
# 66507                          MOTIVATED SELLER -DIVORCE      1
#
# [66508 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 997213 entries, 1 to 997213
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Serial Number     997213 non-null  int64
#  1   List Year         997213 non-null  int64
#  2   Date Recorded     997211 non-null  datetime64[ns]
#  3   Town              997213 non-null  object
#  4   Address           997162 non-null  object
#  5   Assessed Value    997213 non-null  float64
#  6   Sale Amount       997213 non-null  float64
#  7   Sales Ratio       997213 non-null  float64
#  8   Property Type     614767 non-null  object
#  9   Residential Type  608904 non-null  object
#  10  Non Use Code      289681 non-null  object
#  11  Assessor Remarks  149864 non-null  object
#  12  OPM remarks       9934 non-null    object
#  13  Location          197697 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(2), object(8)
# memory usage: 114.1+ MB

# %%
#Number of single families(property type) that sold their house
print(f'The number of single families that sold their house is: {df.loc[df["Property Type"] == "Single Family"].shape[0]}')
df.loc[df["Property Type"] == "Single Family"]
# Out:
# The number of single families that sold their house is: 401612
#         Serial Number  List Year Date Recorded           Town  \
# Index
# 67927          160369       2016    2017-06-28       Trumbull
# 67928          160106       2016    2017-09-05      Thomaston
# 380638          60174       2006    2007-06-29    East Haddam
# 380641          60930       2006    2007-07-02    New Britain
# 380642          60109       2006    2007-05-07     Litchfield
# ...               ...        ...           ...            ...
# 997208         190272       2019    2020-08-03         Wilton
# 997209         190272       2019    2020-06-24     New London
# 997210         190284       2019    2019-11-27      Waterbury
# 997211         190129       2019    2020-04-27  Windsor Locks
# 997212         190504       2019    2020-06-03     Middletown
#
#                     Address  Assessed Value  Sale Amount  Sales Ratio  \
# Index
# ...

# %%
#Number of four family members(residential type) that sold their house
print(f'The number of four family members that sold their house is: {df.loc[df["Residential Type"] == "Four Family"].shape[0]}')
df.loc[df["Residential Type"] == "Four Family"]
# Out:
# The number of four family members that sold their house is: 2418
#         Serial Number  List Year Date Recorded         Town  \
# Index
# 775            200172       2020    2020-11-12      Bristol
# 960            201494       2020    2021-09-09      Danbury
# 2271           200234       2020    2021-06-16   Colchester
# 2658           200116       2020    2021-01-27     Cromwell
# 2904           200179       2020    2021-04-27   Colchester
# ...               ...        ...           ...          ...
# 996057         190242       2019    2019-12-16  New Britain
# 996199         190120       2019    2020-03-20     Plymouth
# 996314         190031       2019    2019-10-04    Waterbury
# 996341          19088       2019    2019-11-06   West Haven
# 997138         190097       2019    2020-02-10     Plymouth
#
#                   Address  Assessed Value  Sale Amount  Sales Ratio  \
# Index
# 775       361 DIVINITY ST        358120.0     223000.0     1.605900
# ...

# %%
#Number of industrial properties sold in the area of Stamford
print(f'The number of industrial properties sold in the area of Stamford is: {df.loc[(df["Town"] == "Stamford") & (df["Property Type"] == "Industrial")].shape[0]}')
df.loc[
    
    (df["Town"] == "Stamford") &
    (df["Property Type"] == "Industrial")
    
]
# Out:
# The number of four family members that sold their house is: 4
#        Serial Number  List Year Date Recorded      Town              Address  \
# Index
# 28736        2001664       2020    2021-05-27  Stamford  44 HOMESTEAD AVENUE
# 32692        2001715       2020    2021-06-02  Stamford     53 LARKIN STREET
# 42895        2001700       2020    2021-06-01  Stamford       0 VIADUCT ROAD
# 48953        2001701       2020    2021-06-01  Stamford     54 POPLAR STREET
#
#        Assessed Value  Sale Amount  Sales Ratio Property Type  \
# Index
# 28736       1151000.0    2500000.0       0.4604    Industrial
# 32692        525110.0    1510000.0       0.3477    Industrial
# 42895       1005280.0    1245000.0       0.8074    Industrial
# 48953        905720.0    1755000.0       0.5160    Industrial
#
#       Residential Type Non Use Code Assessor Remarks OPM remarks Location
# Index
# 28736              NaN          NaN              NaN         NaN      NaN
# ...

# %%
#Number of single families that are in Waterbury or Scotland
print(f'The number of single families that are in Waterbury or Scotland is: {df.loc[(df["Residential Type"] == "Single Family") &((df["Town"] == "Waterbury") |(df["Town"] == "Scotland"))].shape[0]}')
df.loc[
    (df["Residential Type"] == "Single Family") &
    ((df["Town"] == "Waterbury") |
    (df["Town"] == "Scotland"))

]

# df.loc[(df["Residential Type"] == "Single Family") &((df["Town"] == "Waterbury") |(df["Town"] == "Scotland"))]
# Out:
# The number of single families that are in Waterbury or Scotland is: 10752
#         Serial Number  List Year Date Recorded       Town  \
# Index
# 309            201592       2020    2021-05-12  Waterbury
# 27746           20007       2020    2020-11-23   Scotland
# 28223           20034       2020    2021-08-24   Scotland
# 28413           20022       2020    2021-06-02   Scotland
# 29416           20011       2020    2021-01-07   Scotland
# ...               ...        ...           ...        ...
# 997099         191664       2019    2020-09-15  Waterbury
# 997103         191262       2019    2020-07-06  Waterbury
# 997171         190677       2019    2020-02-11  Waterbury
# 997202         191401       2019    2020-07-30  Waterbury
# 997210         190284       2019    2019-11-27  Waterbury
#
#                              Address  Assessed Value  Sale Amount  \
# Index
# 309                     26 COOPER ST         73860.0     122000.0
# ...

# %%
#Properties of Norwalk that are assessed more than 600000
print(f'The number of properties of Norwalk that are assessed more than 600000 is: {df.loc[(df["Town"] == "Norwalk") &(df["Assessed Value"] > 600000)].shape[0]}')
df.loc[
    
    (df["Town"] == "Norwalk") &
    (df["Assessed Value"] > 600000)
    
]
# Out:
# The number of propierties of Norwalk that are assessed more than 600000 is: 2198
#         Serial Number  List Year Date Recorded     Town           Address  \
# Index
# 4675            21922       2002    2003-09-29  Norwalk        5 PLANT CT
# 26130          202925       2020    2021-08-27  Norwalk     18 FLICKER LN
# 26656          200193       2020    2020-11-04  Norwalk   57 ROWAYTON AVE
# 26789          202639       2020    2021-07-08  Norwalk     17 NELSON AVE
# 26974          200995       2020    2021-03-17  Norwalk      13 SAMMIS ST
# ...               ...        ...           ...      ...               ...
# 995525         190296       2019    2019-12-23  Norwalk      467 WEST AVE
# 995931         190176       2019    2019-11-25  Norwalk  189 ROWAYTON AVE
# 996413         190369       2019    2020-01-14  Norwalk      399 MAIN AVE
# 996599         191013       2019    2020-07-28  Norwalk   66 HIGHLAND AVE
# ...

# %%
#Propierties of Norwalk that were sold between 600000 and 700000
print(f'The number of properties of Norwalk that that were sold between 600000 and 700000 is: {df.loc[((df["Sale Amount"]>600000) &(df["Sale Amount"]<700000)) &(df["Town"] == "Norwalk")].shape[0]}')

df.loc[
   ((df["Sale Amount"]>600000) &
    (df["Sale Amount"]<700000)) &
    (df["Town"] == "Norwalk")
]

# df.loc[((df["Sale Amount"]>600000) &(df["Sale Amount"]<700000)) &(df["Town"] == "Norwalk")]
# Out:
# The number of properties of Norwalk that that were sold between 600000 and 700000 is: 1294
#         Serial Number  List Year Date Recorded     Town  \
# Index
# 26059          202829       2020    2021-08-10  Norwalk
# 26144          200108       2020    2020-10-19  Norwalk
# 26511          202654       2020    2021-07-13  Norwalk
# 26620          202284       2020    2021-05-13  Norwalk
# 26844          202359       2020    2021-05-26  Norwalk
# ...               ...        ...           ...      ...
# 993371         190637       2019    2020-04-03  Norwalk
# 994473         190553       2019    2020-03-09  Norwalk
# 994959         190817       2019    2020-06-03  Norwalk
# 995041         190922       2019    2020-07-06  Norwalk
# 996180         190990       2019    2020-07-22  Norwalk
#
#                           Address  Assessed Value  Sale Amount  Sales Ratio  \
# Index
# 26059                 21 THIRD ST        315590.0     675000.0       0.4675
# ...

# %%
#Number of properties that have been sold in 2019
print(f'The number of properties that have been sold in 2019 is: {df.loc[df["Date Recorded"].dt.year == 2019].shape[0]}')

df.loc[df["Date Recorded"].dt.year == 2019]
# Out:
# The number of properties that have been sold in 2019 is: 52622
#         Serial Number  List Year Date Recorded        Town            Address  \
# Index
# 68045          180054       2018    2019-02-07      Hebron  255 MILLSTREAM RD
# 68046          180446       2018    2019-07-11    Branford    167 PHEASANT LA
# 68048          180814       2018    2019-07-02     Bristol      71 HORIZON DR
# 68049          180853       2018    2019-07-18     Bristol   220 EAST MAIN ST
# 68050          180874       2018    2019-03-06  Bridgeport        38 ONDEK ST
# ...               ...        ...           ...         ...                ...
# 997201         190100       2019    2019-11-01   New Haven       55 CARMEL ST
# 997204         190302       2019    2019-11-29   Waterbury     122 WOLCOTT ST
# 997207          19921       2019    2019-11-18  West Haven       75 CLOVER ST
# 997210         190284       2019    2019-11-27   Waterbury    126 PERKINS AVE
# ...

# %%
#Comparison of houses sold in every town in 2015 and 2019

values_2015 = {"Serial Number" : "Total sales 2015"}
sales_2015 = df.loc[df["Date Recorded"].dt.year==2015].groupby("Town")[["Serial Number"]].count().reset_index().rename(columns = values_2015)

values_2016 = {"Serial Number" : "Total sales 2016"}
sales_2016 = df.loc[df["Date Recorded"].dt.year==2016].groupby("Town")[["Serial Number"]].count().reset_index().rename(columns = values_2016)


total_sale = sales_2015.merge(sales_2016, how= "left", left_on="Town", right_on = "Town")

total_sales = total_sale.copy()

total_sales["Total"] = total_sales["Total sales 2015"]-total_sales["Total sales 2016"]
total_sales
# Out:
#               Town  Total sales 2015  Total sales 2016  Total
# 0          Andover                51                41     10
# 1          Ansonia               258               291    -33
# 2          Ashford                54                69    -15
# 3             Avon               410               399     11
# 4      Barkhamsted                57                53      4
# ..             ...               ...               ...    ...
# 164  Windsor Locks               210               240    -30
# 165        Wolcott               248               271    -23
# 166     Woodbridge                33               158   -125
# 167       Woodbury               203               223    -20
# 168      Woodstock               168               149     19
#
# [169 rows x 4 columns]

# %%
#Comparison of houses average sold price in 2012 and 2016 and ordered by price diference


values_2015 = {"Sale Amount" : "Avg price 2015"}
price_2015 = df.loc[df["Date Recorded"].dt.year==2015].groupby("Town")[["Sale Amount"]].mean().reset_index().rename(columns = values_2015)


values_2016 = {"Sale Amount" : "Avg price 2016"}
price_2016 = df.loc[df["Date Recorded"].dt.year==2016].groupby("Town")[["Sale Amount"]].mean().reset_index().rename(columns = values_2016)



total_price = price_2015.merge(price_2016, how= "left", left_on="Town", right_on = "Town")

avg_sales = total_price.copy()

def calculo(avg_sales):
    valor = ((avg_sales["Avg price 2015"] / avg_sales["Avg price 2016"]))*100
    return 100-round(valor,2)
    
avg_sales["% Diference"] = avg_sales.apply(calculo, axis = 1)
# avg_sales
avg_sales.sort_values(by = "% Diference", ascending = False)
# Out:
#            Town  Avg price 2015  Avg price 2016  % Diference
# 118  Rocky Hill   698746.273312    4.136903e+06        83.11
# 134    Stamford   826686.744681    2.554670e+06        67.64
# 82   Middletown   189597.062598    4.098442e+05        53.74
# 150   Waterbury   107246.188018    2.053891e+05        47.78
# 163     Windsor   335497.500000    5.986267e+05        43.96
# ..          ...             ...             ...          ...
# 42   East Haven   338536.309795    2.136893e+05       -58.42
# 162     Windham   220240.198675    1.297663e+05       -69.72
# 12       Bozrah   372189.404762    2.004895e+05       -85.64
# 70      Lebanon   356702.972973    1.744708e+05      -104.45
# 63     Hartford   547359.330391    2.249160e+05      -143.36
#
# [169 rows x 4 columns]

# %%
#Create a column that only is "CHECK" if the sale is between 2011 and 2013, New London town and the assessed price is less  of 500000
df["Check"] = np.where(

    ((df["Date Recorded"].dt.year>= 2011) &
    (df["Date Recorded"].dt.year<= 2013)) &
    (df["Town"]=="New London") & 
    (df["Assessed Value"]>500000), "Check","-")

df.loc[df["Check"] == "Check"]
# Out:
#         Serial Number  List Year Date Recorded        Town  \
# Index
# 568262         100344       2010    2011-09-08  New London
# 568290         100341       2010    2011-09-06  New London
# 569692         100191       2010    2011-06-17  New London
# 569826         100125       2010    2011-03-22  New London
# 571173         100117       2010    2011-03-07  New London
# 574960         100190       2010    2011-06-17  New London
# 576785         100207       2010    2011-07-08  New London
# 584823         100155       2010    2011-04-27  New London
# 585087         100226       2010    2011-08-04  New London
# 586774         100079       2010    2011-01-07  New London
# 588913         100097       2010    2011-02-14  New London
# 597966         110118       2011    2012-03-05  New London
# 600446         110124       2011    2012-03-19  New London
# 603987         110144       2011    2012-04-16  New London
# 604396         110114       2011    2012-03-02  New London
# ...

# %%
#Tranform DataFrame to csv
file = r"C:\Users\Cash\Documents\pruebas_python\proyectos\test.csv"
df.to_csv(file, index = False)

# %%
#Tranform DataFrame to excel
dfx = df.loc[df["Check"] == "Check"].copy()
# dfx.shape

# %%
import openpyxl
file = r"C:\Users\Cash\Documents\pruebas_python\proyectos\test.xlsx"
dfx.to_excel(file, index = False)
wb = openpyxl.load_workbook(file)
# date_format = 
ws = wb["Sheet1"]
for i in range(2,1001):
    ws[f"C{i}"].number_format="DD/MM/YYYY"
wb.save(file)
